# %%
import pandas as pd

# %%
def read_ds(ds_name: str):
  fileName = ds_name+'.csv' 
  with open(fileName, 'r', encoding='utf-8') as f:
    lignes = [line.strip().split(',') for line in f]

  # Trouver le nombre maximal de colonnes
  max_cols = max(len(l) for l in lignes)

  # Normaliser les lignes plus courtes
  for l in lignes:
      l += [''] * (max_cols - len(l))

  # Créer les noms de colonnes
  colonnes = ['util', 'navigateur'] + [f'col{i}' for i in range(3, max_cols + 1)]

  # Créer le DataFrame
  df = pd.DataFrame(lignes, columns=colonnes)

  return df

# %%
features_train = read_ds("train")
features_test = read_ds("test")
print(features_train.shape)
print(features_test.shape)
features_train.head()
# Out:
# (3279, 14470)
# (324, 7726)
#   util      navigateur                                               col3  \
# 0  nuh         Firefox  Création d'un écran(infologic.core.accueil.Acc...
# 1  muz   Google Chrome  Création d'un écran(infologic.core.gui.control...
# 2  zrx  Microsoft Edge  Affichage d'une dialogue(infologic.core.gui.co...
# 3  pou         Firefox  Création d'un écran(infologic.core.gui.control...
# 4  ald   Google Chrome  Affichage d'une dialogue(infologic.acti.module...
#
#                                                 col4  \
# 0                           Affichage d'une dialogue
# 1  Création d'un écran(infologic.core.gui.control...
# 2                              Exécution d'un bouton
# 3                                                 t5
# 4                                                 t5
#
#                            col5  \
# 0         Exécution d'un bouton
# 1                            t5
# 2                      Chainage
# 3  Exécution d'un bouton(MAINT)
# 4         Exécution d'un bouton
#
#                                                 col6  \
# 0                           Fermeture d'une dialogue
# 1  Sélection d’un onglet(infologic.orga.modules.O...
# 2                           Fermeture d'une dialogue
# 3                           Affichage d'une dialogue
# 4                           Fermeture d'une dialogue
#
#                                                 col7  \
# 0                           Affichage d'une dialogue
# 1                                                t10
# 2  Affichage d'une dialogue(infologic.acti.module...
# 3                           Fermeture d'une dialogue
# 4                                                t10
#
#                                             col8                      col9  \
# 0                          Exécution d'un bouton  Fermeture d'une dialogue
# 1                          Exécution d'un bouton                       t15
# 2  Clic sur une grille d'historique de recherche                 Raccourci
# 3                                    Double-clic     Exécution d'un bouton
# 4            Entrée en saisie dans un formulaire                       t10
#
#                                                col10  ... col14461 col14462  \
# 0  Création d'un écran(infologic.core.gui.control...  ...
# 1                              Sélection d’un onglet  ...
# 2                           Fermeture d'une dialogue  ...
# 3  Lancement d'une stat(infologic.core.gui.contro...  ...
# 4                           Affichage d'une dialogue  ...
#
#   col14463 col14464 col14465 col14466 col14467 col14468 col14469 col14470
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 14470 columns]

# %%
actions_par_util = features_train['util'].value_counts()
actions_par_util
# Out:
# util
# skm    75
# slq    71
# cjr    46
# flj    42
# hjs    37
#        ..
# rff     4
# bez     4
# crn     4
# azn     4
# fyg     4
# Name: count, Length: 247, dtype: int64
